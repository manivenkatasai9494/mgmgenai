# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

# %%
messages = [
    SystemMessage(content="You are a helpful assistant powered by Groq LPU technology."),
    HumanMessage(content="explain OOPS in .net")
]

response = llm.invoke(messages)
print(response.content)

# %% [markdown]
# <h1>2. System Message

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

messages = [

    SystemMessage(
        content="You are a funny teacher"
    ),

    HumanMessage(
        content="Explain OOPS in .NET"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>3. Temperature

# %% [markdown]
# <h4>3.1 Low Temperature

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0
)

response = llm.invoke([
    HumanMessage(content="Write story about AI")
])

print(response.content)

# %% [markdown]
# <h4>3.2 High Temperature

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=1
)

response = llm.invoke([
    HumanMessage(content="Write story about AI")
])

print(response.content)

# %% [markdown]
# <h2>4. Multiple Questions

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

questions = [
    "What is C#?",
    "What is ASP.NET?",
    "What is SQL?"
]

for question in questions:

    response = llm.invoke([
        HumanMessage(content=question)
    ])

    print("QUESTION:")
    print(question)

    print("\nANSWER:")
    print(response.content)

    print("\n" + "="*50 + "\n")

# %% [markdown]
# <h2>5. Chat Conversation

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

messages = [

    SystemMessage(
        content="You are .NET trainer"
    ),

    HumanMessage(
        content="What is OOPS?"
    ),

    HumanMessage(
        content="Explain inheritance"
    ),

    HumanMessage(
        content="Explain polymorphism"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>6. AI Code Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.5
)

messages = [

    HumanMessage(
        content="Write C# code example for inheritance"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>7. AI SQL Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.5
)

messages = [

    HumanMessage(
        content="Write sql query to find all users"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>8. AI Debugger

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

buggy_code = """

for i in range(5)
print(i)

"""

messages = [

    HumanMessage(
        content=f"""
Fix this Python code:

{buggy_code}
"""
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>9. AI Translator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    HumanMessage(
        content="Translate 'Welcome to AI world' into hindi"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2> 10. AI Notes Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

topic = "ASP.NET Core"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    HumanMessage(
        content=f"Generate beginner friendly notes on {topic}"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>11. Interactive Chatbot

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

print("AI Chatbot Started")
print("Type 'exit' to stop\n")

while True:

    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Chat Ended")
        break

    response = llm.invoke([
        HumanMessage(content=user_input)
    ])

    print("\nAI:")
    print(response.content)
    print()

# %% [markdown]
# <h2>12. Role-Based AI (.NET Trainer)

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    SystemMessage(
        content="You are expert .NET trainer"
    ),

    HumanMessage(
        content="Explain Dependency Injection"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>13. Prompt Engineering Example

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

prompt = """

Explain OOPS in .NET

Rules:
1. Use simple English
2. Use real life examples
3. Explain each concept separately
4. Give C# examples

"""

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>14. AI MCQ Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    HumanMessage(
        content="Generate 10 MCQs on ASP.NET Core"
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>15. AI Resume Helper

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

prompt = """

Create resume summary for .NET developer
with 2 years experience

Skills:
- ASP.NET Core
- SQL Server
- React
- Azure

"""

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)
# Out:
# **Resume Summary:**
#
# Results-driven .NET developer with 2 years of experience in designing, developing, and deploying scalable web applications using ASP.NET Core. Proficient in database management with SQL Server and skilled in frontend development with React. Experienced in cloud-based solutions using Azure, with a strong passion for delivering high-quality software solutions. Proven ability to work collaboratively in a team environment and adapt to new technologies. Seeking to leverage my skills and experience to contribute to a dynamic and innovative organization.

# %% [markdown]
# <h2>16. Chat History

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, AIMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

chat_history = []

print("AI Chat Started")
print("Type exit to stop\n")

while True:

    user_input = input("You: ")

    if user_input.lower() == "exit":
        break

    # Add user message
    chat_history.append(
        HumanMessage(content=user_input)
    )

    # Get AI response
    response = llm.invoke(chat_history)

    # Print AI response
    print("\nAI:")
    print(response.content)
    print()

    # Store AI response
    chat_history.append(
        AIMessage(content=response.content)
    )
# Out:
# AI Chat Started
# Type exit to stop
#
#
# AI:
# It seems like you've just started our conversation. How can I assist you today? Would you like to chat, ask a question, or discuss a specific topic? I'm here to help.
#
#
# AI:
# **Hello Mani, welcome to the world of Python programming**
#
# Python is a high-level, interpreted programming language that is widely used for various purposes such as web development, scientific computing, data analysis, artificial intelligence, and more. Here's an overview of Python:
#
# ### What is Python?
#
# Python is a programming language that was created in the late 1980s by Guido van Rossum. It is known for its simplicity, readability, and ease of use, making it an ideal language for beginners and experts alike.
#
# ### Features of Python
#
# * **Easy to learn**: Python has a simple syntax and is relatively easy to learn, even for those with no prior programming experience.
# ...

# %% [markdown]
# <h2>17. AI Story Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

topic = input("Enter story topic: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=1
)

prompt = f"""

Write cinematic short story about {topic}

Rules:
1. Add suspense
2. Add emotion
3. Make it cinematic
4. Beginner friendly

"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)
# Out:
# **The Forest of Fear**
#
# The camera pans over a dense, misty forest, the trees towering above like sentinels. The sound of rustling leaves and chirping birds fills the air, but amidst the tranquility, a sense of unease settles in.
#
# We see RAM, a brave and determined prince, walking through the forest, his eyes scanning the surroundings with a mix of caution and concern. He is searching for his beloved wife, SEETHA, who has been kidnapped by the evil king Ravana.
#
# As Ram walks, the camera follows him, capturing the tension in his every step. He calls out Seetha's name, but only the echoes of the forest respond. The camera zooms in on Ram's face, his eyes filled with a deep sense of longing and worry.
#
# Suddenly, a twig snaps behind him. Ram spins around, his hand on the hilt of his sword. The camera pans across the forest, the trees seeming to loom larger, the shadows deepening. A figure emerges from the underbrush, and Ram's heart skips a beat as he sees...
#
# ...

# %% [markdown]
# <h2> 18. AI Interviewer

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

technology = input("Enter technology: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    SystemMessage(
        content="You are strict technical interviewer"
    ),

    HumanMessage(
        content=f"Ask me difficult interview 10 questions on {technology}"
    )
]

response = llm.invoke(messages)

print(response.content)
# Out:
# Here are 10 challenging Java interview questions for you:
#
# 1. **Java Memory Management**: Can you explain the difference between the `Stack` and `Heap` memory areas in Java? How does the garbage collector manage objects in these areas?
#
# 2. **Java Multithreading**: Write a Java program to demonstrate the use of `synchronized` blocks and `Lock` objects to achieve thread safety in a multithreaded environment. Explain the advantages and disadvantages of each approach.
#
# 3. **Java Generics**: Suppose you have a generic class `Box<T>` with a method `void add(T t)`. How would you implement a method `void addAll(Box<? extends T> box)` that adds all elements from the given box to the current box? Provide a detailed explanation of the wildcard `? extends T` and its implications.
#
# ...

# %% [markdown]
# <h2>19. AI Meme Generator Ideas

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

topic = input("Enter meme topic: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=1
)

prompt = f"""

Generate 10 meme ideas about {topic}

Format:
Meme Caption:
Meme Situation:

"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>20. AI Motivational Coach

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

problem = input("What problem are you facing? ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

messages = [

    SystemMessage(
        content="You are motivational life coach"
    ),

    HumanMessage(
        content=problem
    )
]

response = llm.invoke(messages)

print(response.content)

# %% [markdown]
# <h2>21. AI Code Reviewer

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

code = input("Paste code here:\n")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""

Review this code:

{code}

Give:
1. Mistakes
2. Improvements
3. Optimized version

"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>22. AI Exam Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

subject = input("Enter subject: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""

Generate question paper for {subject}

Include:
1. MCQs
2. Short questions
3. Coding questions

"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>23. AI Email Reply Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

email = input("Paste email:\n")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Write professional reply for this email:

{email}
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>24. Notes to MCQ Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

notes = input("Paste notes:\n")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Generate MCQs from these notes:

{notes}
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>25. SQL to English Converter

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

query = input("Enter SQL query:\n")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Explain this SQL query in simple English:

{query}
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>26. Resume Skill Extractor

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

resume = input("Paste resume:\n")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Extract technical skills from this resume:

{resume}
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>27.Learning Roadmap Generator

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

topic = input("Enter technology: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Create complete learning roadmap for:

{topic}

Include:
1. Beginner
2. Intermediate
3. Advanced
4. Projects
5. Interview prep
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)

# %% [markdown]
# <h2>28. AI Architecture Explainer

# %%
import os
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage

os.environ["GROQ_API_KEY"] = "YOUR_API_KEY"

concept = input("Enter concept: ")

llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

prompt = f"""
Explain architecture of:

{concept}

Include:
1. Components
2. Flow
3. Real-time example
4. Advantages
"""

response = llm.invoke([
    HumanMessage(content=prompt)
])

print(response.content)
